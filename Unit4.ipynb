# %% [markdown]
# # Regression

# %% [markdown]
# ## Simple Linear Regression

# %%
import pandas as pd
df=pd.read_csv("Book1.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
print(x)
print(y)
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=140)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(y_test)
y_pred=(lr.predict(x_test))
print(y_pred)
# Out:
# 129    3.12
# 30     3.26
# 142    3.04
# 120    1.73
# 47     3.26
# 49     4.62
# 71     3.34
# 95     2.79
# 140    3.15
# 21     2.93
# 169    4.37
# 46     2.26
# 137    3.13
# 173    2.56
# 145    2.18
# 61     1.61
# 55     3.39
# 154    2.85
# 153    3.99
# 132    2.48
# 89     2.72
# 116    3.33
# 23     2.48
# 130    2.49
# 11     2.60
# 14     3.42
# 81     2.20
# 59     3.31
# 45     3.58
# 177    3.64
# 96     2.61
# 32     3.08
# 16     2.35
# 110    3.76
# 178    3.63
# 91     2.14
# 37     2.43
# 115    4.21
# 8      2.31
# 24     2.71
# Name: package, dtype: float64
# [3.17648342 3.21584506 2.97405209 2.01812638 2.36113502 4.06493202
#  3.27769908 2.80535932 3.52511515 2.92906735 4.31234808 2.49046614
#  3.09213703 2.87283643 2.36113502 2.15870369 3.68818483 3.05839848
#  3.54198442 2.36113502 2.68727438 4.16052459 2.55794325 2.83347478
#  2.79411313 3.42389948 2.50733542 3.32830691 3.50262278 3.06402157
#  3.07526775 2.99092137 2.92344426 3.67693864 3.66006936 2.57481253
#  2.39487357 3.77253121 2.50171233 2.74912839]

# %%
m=lr.coef_
m
# Out:
# array([0.56230924])

# %%
c=lr.intercept_
c
# Out:
# np.float64(-0.9227509551098896)

# %%
y_pred=(lr.predict(x_test))
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("mae:",mean_absolute_error(y_test,y_pred))
print("mse:",mean_squared_error(y_test,y_pred))
print("r2score:",r2_score(y_test,y_pred))
# Out:
# mae: 0.24113305838850313
# mse: 0.11140838611339383
# r2score: 0.7577908753094237

# %%
import numpy as np
x_t=np.array([8.9]).reshape(-1,1)
x_t
# Out:
# array([[8.9]])

# %%
predicted=lr.predict(x_t)
predicted
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([4.0818013])

# %%
import matplotlib.pyplot as plt
plt.scatter(df["cgpa"],df["package"])
plt.scatter(x_test,y_test,color="red")
plt.plot(x_test,y_pred,color="green")
plt.show()

# %%
df1=pd.read_csv("advertising.csv")
df1
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
x=df1.iloc[:,0:1]
y=df1.iloc[:,-1]
print(x)
print(y)
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=140)

# %%
from sklearn.linear_model import LinearRegression
lr1=LinearRegression()
lr1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(y_test)
y_pred=(lr.predict(x_test))
# print(y_pred)
# Out:
# 48    41.514822
# 16     6.689123
# 29     0.953115
# 44    28.912188
# 0     41.842986
# 4     32.284531
# 45    17.843957
# 11    18.123991
# 2     39.383001
# 35    10.336631
# Name: Ice Cream Sales (units), dtype: float64

# %%
m=lr.coef_
m

# %%
c=lr.intercept_
c

# %%
y_pred=(lr.predict(x_test))
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
# print("mae:",mean_absolute_error(y_test,y_pred))
print("mse:",mean_squared_error(y_test,y_pred))
print("r2score:",r2_score(y_test,y_pred))

# %% [markdown]
# ## Multiple Linear Regression

# %%
import pandas as pd
df=pd.read_csv("car data.csv")
df

# %% [markdown]
# ## Polynomial Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({"temp":[0,20,40,60,80,100],"pressure":[0.0002,0.0012,0.0060,0.0300,0.0900,0.2700]})
x = df.iloc[:,0:1]
y = df.iloc[:,-1]
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
y_pred = model.predict(x)
plt.scatter(df["temp"],y)
plt.plot(df["temp"],y_pred)

# %%
df=pd.DataFrame({"temp":[0,20,40,60,80,100],"pressure":[0.0002,0.0012,0.0060,0.0300,0.0900,0.2700]})
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
model_poly=poly.fit_transform(x)
model=LinearRegression()
model.fit(model_poly,y)
y_pred1=model.predict(model_poly)

import matplotlib.pyplot as plt
plt.scatter(df["temp"],y)
plt.plot(df["temp"],y_pred)
plt.plot(df["temp"],y_pred1)

# %% [raw]
# Write a python program to compare r2score & mse for simple linear regression and polynomial linear regression for Ice_cream selling data.csv
# (Note: for the polynomial transformation take degree=4)

# %% [markdown]
# ### without splitting

# %%
import pandas as pd
df=pd.read_csv("Ice_cream selling data.csv")
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
y_pred=lr.predict(x)
from sklearn.metrics import mean_squared_error,r2_score
print("mse:",mean_squared_error(y,y_pred))
print("r2score:",r2_score(y,y_pred))
# Out:
# mse: 142.83040442368952
# r2score: 0.030689536411547258

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=4)
model_poly=poly.fit_transform(x)
model=LinearRegression()
model.fit(model_poly,y)
y_pred1=model.predict(model_poly)
from sklearn.metrics import mean_squared_error,r2_score
print("mse:",mean_squared_error(y,y_pred1))
print("r2score:",r2_score(y,y_pred1))
# Out:
# mse: 8.274534314947282
# r2score: 0.9438453407370606

# %% [markdown]
# ### with splitting

# %%
import pandas as pd
df=pd.read_csv("Ice_cream selling data.csv")
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(model_poly,y,test_size=0.2,
                                                 random_state=40)
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred1=lr.predict(x_test)
from sklearn.metrics import mean_squared_error,r2_score
print("mse:",mean_squared_error(y_test,y_pred1))
print("r2score:",r2_score(y_test,y_pred1))
# Out:
# mse: 14.361010657087359
# r2score: 0.9297417074068742

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=4)
model_poly=poly.fit_transform(x)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(model_poly,y,test_size=0.2,
                                                 random_state=40)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred2=model.predict(x_test)
from sklearn.metrics import mean_squared_error,r2_score
print("mse:",mean_squared_error(y_test,y_pred2))
print("r2score:",r2_score(y_test,y_pred2))
# Out:
# mse: 14.361010657087359
# r2score: 0.9297417074068742

# %% [markdown]
# # kNN - k Nearest Neighbours

# %% [raw]
# Model accuracy= TP+TN / TP+FP+FN+TN

# %%
import pandas as pd
df=pd.read_csv("diabetes.csv")
print(df.info())
x=df.iloc[:,0:8]
y=df.iloc[:,-1]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,
                                                 random_state=40)

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=25)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)

#confusion metrics
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None
# array([[88,  7],
#        [32, 27]])

# %%
TN=cm[0][0]
FP=cm[0][1]
FN=cm[1][0]
TP=cm[1][1]

acc=(TP+TN)/(TP+FP+FN+TN)
sens=TP/(TP+FN)
spec=TN/(TN+FP)
print("Accuracy:",acc)
print("Specificity:",spec)
print("Sensitivity:",sens)
# Out:
# Accuracy: 0.7467532467532467
# Specificity: 0.9263157894736842
# Sensitivity: 0.4576271186440678
